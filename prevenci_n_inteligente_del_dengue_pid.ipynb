# %% [markdown]
# <a href="https://colab.research.google.com/github/NicolasB7/PID/blob/main/prevenci_n_inteligente_del_dengue_pid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CONECTARSE A DRIVE.**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **SE IMPORTAN LAS BASE DE DATOS Y SE CREA UN DATARFRAME.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

d2020 = 'drive/Shareddrives/PID/Dengue/dengue_abierto2020.csv'
d2021 = 'drive/Shareddrives/PID/Dengue/dengue_abierto2021.csv'
d2022 = 'drive/Shareddrives/PID/Dengue/dengue_abierto2022.csv'
d2023 = 'drive/Shareddrives/PID/Dengue/dengue_abierto2023.csv'
datosHistoricos = pd.concat(map(pd.read_csv, [d2020, d2021, d2022, d2023]), ignore_index=True)
datosHistoricos
# Out:
#        FECHA_ACTUALIZACION  ID_REGISTRO  SEXO  EDAD_ANOS  ENTIDAD_RES  \
# 0               2020-12-30       404569     2         63           28
# 1               2020-12-30       760644     1         42           18
# 2               2020-12-30       760647     2         16           31
# 3               2020-12-30       760654     1         76           12
# 4               2020-12-30       760657     1         20           30
# ...                    ...          ...   ...        ...          ...
# 217952          2023-02-13      1005253     1         45           23
# 217953          2023-02-13      1005240     2         32           23
# 217954          2023-02-13      1005269     2          0           16
# 217955          2023-02-13      1005272     1         65           31
# 217956          2023-02-13      1005282     1         15            6
#
#         MUNICIPIO_RES  HABLA_LENGUA_INDIG  INDIGENA  ENTIDAD_UM_NOTIF  \
# 0                  33                   2         1                28
# 1                   8                   2         2                18
# 2                  96                   2         2                31
# 3                   1                   2         2                12
# 4                 142                   2         2                30
# ...               ...                 ...       ...               ...
# 217952              5                   2         2                23
# 217953              5                   2         2                23
# 217954             52                   2         2                16
# 217955             96                   2         2                31
# 217956              7                   2         2                 6
#
#         MUNICIPIO_UM_NOTIF  ...  INMUNOSUPR CIRROSIS_HEPATICA  EMBARAZO  \
# 0                       33  ...           2                 2         2
# 1                       17  ...           2                 2         2
# 2                       96  ...           2                 2         2
# 3                        1  ...           2                 2         2
# 4                      116  ...           2                 2         2
# ...                    ...  ...         ...               ...       ...
# 217952                   5  ...           2                 2         2
# 217953                   5  ...           2                 2         2
# 217954                  52  ...           2                 2         2
# 217955                  96  ...           2                 2         2
# 217956                   7  ...           2                 2         2
#
#         DEFUNCION  DICTAMEN  TOMA_MUESTRA  RESULTADO_PCR  ESTATUS_CASO  \
# 0               2       5.0             1              5             2
# 1               2       5.0             2              5             1
# 2               2       5.0             2              5             1
# 3               2       5.0             1              5             3
# 4               2       5.0             1              5             2
# ...           ...       ...           ...            ...           ...
# 217952          2       5.0             1              5             3
# 217953          2       5.0             2              5             1
# 217954          2       5.0             2              5             1
# 217955          2       5.0             1              5             3
# 217956          2       5.0             1              2             2
#
#         ENTIDAD_ASIG  MUNICIPIO_ASIG
# 0                 28              33
# 1                 18               8
# 2                 31              96
# 3                 12               1
# 4                 30             142
# ...              ...             ...
# 217952            23               5
# 217953            23               5
# 217954            16              52
# 217955            23               5
# 217956             6               7
#
# [217957 rows x 28 columns]

# %% [markdown]
# **DESCRIPTOR DE TERMINOS.**

# %%
pd.read_excel('drive/Shareddrives/PID/Dengue/Descriptores_Dengue.xlsx') # Descriptor de terminos.
# Out:
#     NO.      NOMBRE DE VARIABLE  \
# 0     1     FECHA_ACTUALIZACION
# 1     2             ID_REGISTRO
# 2     3                    SEXO
# 3     4               EDAD_ANOS
# 4     5             ENTIDAD_RES
# 5     6           MUNICIPIO_RES
# 6     7      HABLA_LENGUA_INDIG
# 7     8                INDIGENA
# 8     9        ENTIDAD_UM_NOTIF
# 9    10      MUNICIPIO_UM_NOTIF
# 10   11    INSTITUCION_UM_NOTIF
# 11   12     FECHA_SIGN_SINTOMAS
# 12   13           TIPO_PACIENTE
# 13   14            HEMORRAGICOS
# 14   15                DIABETES
# 15   16            HIPERTENSION
# 16   17  ENFERMEDAD ULC_PEPTICA
# 17   18        ENFERMEDAD_RENAL
# 18   19              INMUNOSUPR
# 19   20       CIRROSIS_HEPATICA
# 20   21                EMBARAZO
# 21   22               DEFUNCION
# 22   23                DICTAMEN
# 23   24            TOMA_MUESTRA
# 24   25           RESULTADO PCR
# 25   26            ESTATUS_CASO
# 26   27            ENTIDAD_ASIG
# 27   28          MUNICIPIO_ASIG
#
#                                           DESCRIPCION  \
# 0   LA BASE DE DATOS SE ACTUALIZA SEMANALMENTE. ES...
# 1                    NÚMERO DE INDETIFICADOR DEL CASO
# 2                     IDENTIFICA EL SEXO DEL PACIENTE
# 3             IDENTIFICA LA EDAD EN AÑOS DEL PACIENTE
# 4    IDENTIFICA LA ENTIDAD DE RESIDENCIA DEL PACIENTE
# 5   IDENTIFICA EL MUNICIPIO DE RESIDENCIA DEL PACI...
# 6     IDENTIFICA SI EL PACIENTE HABLA LENGUA INDIGENA
# 7   IDENTIFICA SI EL PACIENTE SE AUTOIDENTIFICA CO...
# 8   IDENTIFICA LA ENTIDAD DONDE SE ENCUENTRA LA UN...
# 9   IDENTIFICA EL MUNICIPIO DONDE SE ENCUENTRA LA ...
# 10  IDENTIFICA LA INSTITUCIÓN DE LA UNIDAD MEDICA ...
# 11  IDENTIFICA LA FECHA DE INICIO DE SIGNOS Y SINT...
# 12  IDENTIFICA EL TIPO DE ATENCIÓN QUE RECIBIÓ EL ...
# 13               PRESENCIA DE TRASTORNOS HEMORRÁGICOS
# 14                              PRESENCIA DE DIABETES
# 15                         PRESENCIA DE HIPERTENSIÓN
# 16             PRESENCIA DE ENFERMEDAD ULCERO PÉPTICA
# 17                     PRESENCIA DE ENFERMEDAD RENAL
# 18                       PRESENCIA DE INMUNOSUPRESIÓN
# 19                     PRESENCIA DE CIRROSIS HEPÁTICA
# 20       IDENTIFICA SI LA PACIENTE ESTÁ EMBARAZADA
# 21                     INDICA SI EL PACIENTE FALLECIÓ
# 22  IDENTIFICA EL RESULTADO DE LA DICTAMINACIÓN PA...
# 23       IDENTIFICA SI AL PACIENTE SE LE TOMÓ MUESTRA
# 24  IDENTIFICA EL RESULTADO DE LA PRUEBA PCR REALI...
# 25                                   ESTATUS DEL CASO
# 26   IDENTIFICA LA ENTIDAD A LA QUE SE ASIGNÓ EL CASO
# 27   IDENTIFICA EL MUNICIPIO AL QUE SE ASIGNÓ EL CASO
#
#                                   FORMATO O FUENTE
# 0   AAAA-MM-DD, 9999-99-99: CUANDO NO HAY REGISTRO
# 1                                           TEXTO
# 2                                   CATÁLOGO: SEXO
# 3                                 NÚMERICA EN AÑOS
# 4                              CATÁLOGO: ENTIDADES
# 5                             CATÁLOGO: MUNICIPIOS
# 6                                 CATÁLOGO: SI /NO
# 7                                 CATÁLOGO: SI /NO
# 8                              CATÁLOGO: ENTIDADES
# 9                             CATÁLOGO: MUNICIPIOS
# 10                           CATÁLOGO: INSTITUCIÓN
# 11  AAAA-MM-DD, 9999-99-99: CUANDO NO HAY REGISTRO
# 12                         CATÁLOGO: TIPO_PACIENTE
# 13                                CATÁLOGO: SI /NO
# 14                                CATÁLOGO: SI /NO
# 15                                CATÁLOGO: SI /NO
# 16                                CATÁLOGO: SI /NO
# 17                                CATÁLOGO: SI /NO
# 18                                CATÁLOGO: SI /NO
# 19                                CATÁLOGO: SI /NO
# 20                                CATÁLOGO: SI /NO
# 21                                CATÁLOGO: SI /NO
# 22                              CATÁLOGO: DICTAMEN
# 23                                CATÁLOGO: SI /NO
# 24                         CATÁLOGO: RESULTADO_PCR
# 25                          CATÁLOGO: ESTATUS_CASO
# 26                             CATÁLOGO: ENTIDADES
# 27                            CATÁLOGO: MUNICIPIOS

# %% [markdown]
# **HOJAS DEL CATALOGO.**

# %%
hojas = pd.read_excel('drive/Shareddrives/PID/Dengue/Catálogos_Dengue.xlsx', sheet_name=None) # Hojas del catalogo
catalogo = []
catalogo = list(hojas.keys())
print(catalogo)
# Out:
# ['CATÁLOGO ESTATUS_CASO', 'CATALOGO RESULTADO_PCR ', 'CATÁLOGO DICTAMEN', 'CATÁLOGO INSTITUCION', 'CATÁLOGO TIPO_PACIENTE', 'CATÁLOGO MUNICIPIO', 'CATÁLOGO ENTIDAD', 'CATALOGO SI_NO', 'CATÁLOGO SEXO']

# %% [markdown]
# **SE BUSCA A JALISCO EN EL CATALOGO ENTIDAD.**

# %%
entidades = pd.read_excel('drive/Shareddrives/PID/Dengue/Catálogos_Dengue.xlsx', sheet_name='CATÁLOGO ENTIDAD') # SE BUSCA A JALISCO EN EL CATALOGO ENTIDAD
jalisco = entidades[entidades.ENTIDAD_FEDERATIVA.eq('JALISCO')]
jalisco
# Out:
#     CLAVE_ENTIDAD ENTIDAD_FEDERATIVA ABREVIATURA
# 13             14            JALISCO          JC

# %% [markdown]
# **CASOS CONFIRMADOS EN JALISCO.**

# %%
casosEnJalisco = datosHistoricos[datosHistoricos.ENTIDAD_UM_NOTIF.eq(14)] # Casos confirmados en Jalisco
casosEnJalisco
# Out:
#        FECHA_ACTUALIZACION  ID_REGISTRO  SEXO  EDAD_ANOS  ENTIDAD_RES  \
# 13              2020-12-30       760702     2         46           14
# 17              2020-12-30       760721     2         45           14
# 20              2020-12-30       760737     2         32           14
# 29              2020-12-30       760773     1         22           14
# 94              2020-12-30       760241     2         12           18
# ...                    ...          ...   ...        ...          ...
# 217861          2023-02-13      1001538     1         27           14
# 217891          2023-02-13      1006217     2          0           14
# 217898          2023-02-13      1006300     1         19           14
# 217907          2023-02-13      1006316     1         91           14
# 217922          2023-02-13      1006493     2         15           14
#
#         MUNICIPIO_RES  HABLA_LENGUA_INDIG  INDIGENA  ENTIDAD_UM_NOTIF  \
# 13                 39                   2         2                14
# 17                 67                   2         2                14
# 20                 98                   2         2                14
# 29                 39                   2         2                14
# 94                 20                   2         2                14
# ...               ...                 ...       ...               ...
# 217861             39                   2         2                14
# 217891             98                   2         2                14
# 217898             63                   2         2                14
# 217907            120                   2         2                14
# 217922            120                   2         2                14
#
#         MUNICIPIO_UM_NOTIF  ...  INMUNOSUPR CIRROSIS_HEPATICA  EMBARAZO  \
# 13                      39  ...           2                 2         2
# 17                      67  ...           2                 2         2
# 20                      39  ...           2                 2         2
# 29                      39  ...           2                 2         2
# 94                      67  ...           2                 2         2
# ...                    ...  ...         ...               ...       ...
# 217861                  98  ...           2                 2         2
# 217891                  39  ...           2                 2         2
# 217898                  39  ...           2                 2         1
# 217907                 120  ...           2                 2         2
# 217922                 120  ...           2                 2         2
#
#         DEFUNCION  DICTAMEN  TOMA_MUESTRA  RESULTADO_PCR  ESTATUS_CASO  \
# 13              2       5.0             2              5             1
# 17              2       5.0             2              5             1
# 20              2       5.0             2              5             1
# 29              2       5.0             1              5             3
# 94              2       5.0             1              2             2
# ...           ...       ...           ...            ...           ...
# 217861          2       5.0             1              5             3
# 217891          2       5.0             2              5             1
# 217898          2       5.0             1              5             1
# 217907          2       5.0             1              5             3
# 217922          2       5.0             1              5             1
#
#         ENTIDAD_ASIG  MUNICIPIO_ASIG
# 13                14              39
# 17                14              67
# 20                14              98
# 29                14              39
# 94                18              20
# ...              ...             ...
# 217861            14              39
# 217891            14              98
# 217898            14              63
# 217907            14             120
# 217922            14             120
#
# [30300 rows x 28 columns]

# %% [markdown]
# **SE BUSCA LA CLAVE DE CASOS CONFIRMADOS.**

# %%
pd.read_excel('drive/Shareddrives/PID/Dengue/Catálogos_Dengue.xlsx', sheet_name=catalogo[0]) # Se busca la clave de casos confirmados
# Out:
#    CLAVE DESCRIPCIÓN
# 0      1    PROBABLE
# 1      2  CONFIRMADO
# 2      3  DESCARTADO

# %% [markdown]
# **CASOS CONFIRMADOS EN JALISCO.**

# %%
casosEnJaliscoConfirmados = casosEnJalisco[casosEnJalisco.ESTATUS_CASO.eq(2)] # Casos confirmados
casosEnJaliscoConfirmados
# Out:
#        FECHA_ACTUALIZACION  ID_REGISTRO  SEXO  EDAD_ANOS  ENTIDAD_RES  \
# 94              2020-12-30       760241     2         12           18
# 105             2020-12-30       760360     2         44           14
# 335             2020-12-30       760381     1         18           14
# 371             2020-12-30       761374     2         33           14
# 390             2020-12-30       761451     1         20           14
# ...                    ...          ...   ...        ...          ...
# 214154          2023-02-13      1007009     2         10           14
# 215101          2023-02-13      1002231     1         55           14
# 216717          2023-02-13      1003197     2         33           14
# 216764          2023-02-13      1003019     1         25           14
# 217044          2023-02-13      1004815     2         30            6
#
#         MUNICIPIO_RES  HABLA_LENGUA_INDIG  INDIGENA  ENTIDAD_UM_NOTIF  \
# 94                 20                   2         2                14
# 105                39                   2         2                14
# 335               120                   2         2                14
# 371                70                   2         2                14
# 390               100                   2         2                14
# ...               ...                 ...       ...               ...
# 214154             22                   2         2                14
# 215101              5                   2         2                14
# 216717            100                   2         2                14
# 216764             99                   1         1                14
# 217044              7                   2         2                14
#
#         MUNICIPIO_UM_NOTIF  ...  INMUNOSUPR CIRROSIS_HEPATICA  EMBARAZO  \
# 94                      67  ...           2                 2         2
# 105                     39  ...           2                 2         2
# 335                     39  ...           2                 2         2
# 371                     39  ...           2                 2         2
# 390                     67  ...           2                 2         1
# ...                    ...  ...         ...               ...       ...
# 214154                  22  ...           2                 2         2
# 215101                  39  ...           2                 2         2
# 216717                  67  ...           2                 2         2
# 216764                  99  ...           2                 2         2
# 217044                  22  ...           2                 2         2
#
#         DEFUNCION  DICTAMEN  TOMA_MUESTRA  RESULTADO_PCR  ESTATUS_CASO  \
# 94              2       5.0             1              2             2
# 105             2       5.0             1              2             2
# 335             2       5.0             1              2             2
# 371             2       5.0             1              5             2
# 390             2       5.0             1              2             2
# ...           ...       ...           ...            ...           ...
# 214154          2       5.0             1              2             2
# 215101          2       5.0             1              5             2
# 216717          2       5.0             1              2             2
# 216764          2       5.0             1              4             2
# 217044          2       5.0             1              2             2
#
#         ENTIDAD_ASIG  MUNICIPIO_ASIG
# 94                18              20
# 105               14              39
# 335               14             120
# 371               18              20
# 390               14             100
# ...              ...             ...
# 214154            14              22
# 215101            14               5
# 216717            14             100
# 216764             7              31
# 217044             6               7
#
# [5675 rows x 28 columns]

# %% [markdown]
# **MUNICIPIOS DE JALISCO.**

# %%
municipios = pd.read_excel('drive/Shareddrives/PID/Dengue/Catálogos_Dengue.xlsx', sheet_name=catalogo[5]) # Se busca los municipios del estado de Jalisco
municipios[municipios.CLAVE_ENTIDAD.eq('14')]
# Out:
#      CLAVE_MUNICIPIO                MUNICIPIO CLAVE_ENTIDAD
# 549                1                   ACATIC            14
# 550                2        ACATLÁN DE JUÁREZ            14
# 551                3     AHUALULCO DE MERCADO            14
# 552                4                 AMACUECA            14
# 553                5                 AMATITÁN            14
# ..               ...                      ...           ...
# 670              122    ZAPOTITLÁN DE VADILLO            14
# 671              123         ZAPOTLÁN DEL REY            14
# 672              124              ZAPOTLANEJO            14
# 673              125  SAN IGNACIO CERRO GORDO            14
# 674              999          NO ESPECIFICADO            14
#
# [126 rows x 3 columns]

# %% [markdown]
# **CONTAGIOS CONFIRMADOS EN EL MUNICIPIO DE ZAPOPAN.**

# %%
casosEnJaliscoConfirmados[casosEnJaliscoConfirmados.MUNICIPIO_UM_NOTIF.eq(120)] #Contagios en el municipio de Zapopan
# Out:
#        FECHA_ACTUALIZACION  ID_REGISTRO  SEXO  EDAD_ANOS  ENTIDAD_RES  \
# 1616            2020-12-30       762625     1         46           14
# 2424            2020-12-30       764481     1         13           14
# 4080            2020-12-30       763793     1          8           14
# 4552            2020-12-30       767210     1         15           14
# 4773            2020-12-30       765928     1         57           14
# ...                    ...          ...   ...        ...          ...
# 203621          2022-12-12       978263     1         53           14
# 205974          2022-12-12       954149     1         16           14
# 208915          2022-12-12       940778     1         24           14
# 209899          2022-12-12       943215     1         23           14
# 213643          2023-02-13      1002271     1          7           14
#
#         MUNICIPIO_RES  HABLA_LENGUA_INDIG  INDIGENA  ENTIDAD_UM_NOTIF  \
# 1616               98                   2         2                14
# 2424              120                   2         2                14
# 4080               94                   2         2                14
# 4552              120                   2         2                14
# 4773               39                   2         2                14
# ...               ...                 ...       ...               ...
# 203621            120                   2         2                14
# 205974            120                   2         2                14
# 208915            120                   2         2                14
# 209899            120                   2         2                14
# 213643             98                   2         2                14
#
#         MUNICIPIO_UM_NOTIF  ...  INMUNOSUPR CIRROSIS_HEPATICA  EMBARAZO  \
# 1616                   120  ...           2                 2         2
# 2424                   120  ...           2                 2         2
# 4080                   120  ...           2                 2         2
# 4552                   120  ...           2                 2         2
# 4773                   120  ...           2                 2         2
# ...                    ...  ...         ...               ...       ...
# 203621                 120  ...           2                 2         2
# 205974                 120  ...           2                 2         2
# 208915                 120  ...           2                 2         1
# 209899                 120  ...           2                 2         2
# 213643                 120  ...           2                 2         2
#
#         DEFUNCION  DICTAMEN  TOMA_MUESTRA  RESULTADO_PCR  ESTATUS_CASO  \
# 1616            2       5.0             1              5             2
# 2424            2       5.0             1              5             2
# 4080            2       5.0             1              5             2
# 4552            2       5.0             1              5             2
# 4773            2       5.0             1              5             2
# ...           ...       ...           ...            ...           ...
# 203621          2       5.0             1              5             2
# 205974          2       5.0             1              2             2
# 208915          2       5.0             1              5             2
# 209899          2       5.0             1              1             2
# 213643          2       5.0             1              5             2
#
#         ENTIDAD_ASIG  MUNICIPIO_ASIG
# 1616              14              98
# 2424              14             120
# 4080              14              94
# 4552              14             120
# 4773              14              39
# ...              ...             ...
# 203621            14             120
# 205974            14             120
# 208915            14             120
# 209899            14             120
# 213643             6               7
#
# [414 rows x 28 columns]
